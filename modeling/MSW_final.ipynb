# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
from tqdm.notebook import tqdm

# %%
june = pd.read_csv("june.csv",encoding = 'cp949',low_memory =False)
july = pd.read_csv("july.csv", encoding = 'cp949', low_memory =False)
august = pd.read_csv("august.csv", encoding = 'cp949', low_memory = False)
df = pd.concat([june, july,august], ignore_index=True)

# %%
df = df.rename(columns = {'strd_date':'기준일자', 'strd_tizn_val':'기준시간대값', 'ctpr_nm':'시도명', 'ccg_nm':'시군구명', 'adn_dgnm':'행정동명',
       'adng_no':'행정동번호', 'cardc_nm':'카드사명', 'tpbuz_cd':'업종코드', 'tpbuz_nm':'업종명', 'bth_yr':'출생년도', 'sex_cd':'성별코드',
       'trns_cnt':'거래건수', 'ttl_trns_amt':'총거래금액'})

# %%
# 불필요한 변수제거
df=df.drop(['시도명'], axis=1)
df=df.drop(['행정동번호'], axis=1)
#df=df.drop(['업종명'], axis=1)
df=df.drop(['행정동명'], axis=1)
df.drop(df[df['출생년도']==4607].index ,inplace=True, axis = 0)
df.drop(df[df['출생년도']==3688].index ,inplace=True, axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27135019 entries, 0 to 27135159
# Data columns (total 9 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   기준일자    int64
#  1   기준시간대값  int64
#  2   시군구명    object
#  3   카드사명    object
#  4   업종코드    int64
#  5   출생년도    int64
#  6   성별코드    object
#  7   거래건수    int64
#  8   총거래금액   int64
# dtypes: int64(6), object(3)
# memory usage: 2.0+ GB

# %%
# 기준일자 날짜형 변수로 변경
df=df.astype({'기준일자' : str})

# %%
df['기준일자']=pd.to_datetime(df['기준일자'])
from datetime import datetime
df['요일']=df['기준일자'].dt.day_name()
from pandas import DataFrame

# %%
# 나이 변수를 이용해 출생년도 생성
df['age']=2022-df['출생년도']+1
df['age_range'] = df['age']//10*10

# %%
df=df.drop(['age'], axis=1)
df=df.drop(['출생년도'], axis=1)

# %%
# 건당 거래금액 변수 생성 후 10원 미만 행 삭제
df['거래금액']=df['총거래금액']//df['거래건수']

# %%
df=df.drop(df[df['거래금액']<10].index, axis=0)

# %%
# 범주형 변수 범주형으로 변환
df['시군구명']=df['시군구명'].astype('str')
df['카드사명']=df['카드사명'].astype('category')
df['시군구명']=df['시군구명'].astype('category')
df['성별코드']=df['성별코드'].astype('category')
df['요일']=df['요일'].astype('category')
df['age_range']=df['age_range'].astype('category')

# %%
# 중분류 생성
code=pd.read_csv("업종코드_중분류.csv")
df=pd.merge(df,code, left_on='업종코드', right_on='업종코드', how='left')

# %%
#df=df.drop(['중분류_x'], axis=1)
#df=df.drop(['중분류_y'], axis=1)

# %%
df['업종코드']=df['업종코드'].astype('category')
df['중분류']=df['중분류'].astype('category')

# %%
df['시군구명']=df['시군구명'].astype('str')
df['업종코드']=df['업종코드'].astype('str')

# %%
hobby = df['중분류']=='문화/취미'
hobby
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 27134903    False
# 27134904    False
# 27134905    False
# 27134906    False
# 27134907    False
# Name: 중분류, Length: 27134908, dtype: bool

# %%
h= df['시군구명']=='해운대구'
y= df['시군구명']=='연제구'

# %%
hhy = df[hobby&(h | y)]

# %%
hhy['업종명'].value_counts()
# Out:
# 애완동물      5694
# 화원        4354
# DP&E      4111
# 영화관       2256
# 액세서리      2122
# 문화취미기타     540
# 악기점        111
# 화랑         108
# 화방표구점       87
# 수족관         32
# 민예공예품       19
# 카메라          7
# Name: 업종명, dtype: int64

# %%
sub=hhy.groupby(['업종명']).max('거래금액')['거래금액'].reset_index(name='거래금액')
sub
# Out:
#        업종명     거래금액
# 0     DP&E  1500000
# 1   문화취미기타   830000
# 2    민예공예품   330000
# 3      수족관    70000
# 4      악기점   500000
# 5     애완동물   690000
# 6     액세서리  1000000
# 7      영화관   114000
# 8      카메라    68500
# 9       화랑   360000
# 10   화방표구점   200000
# 11      화원   500000

# %%
costume = df['중분류']=='의류/패션잡화'
jg = df['시군구명'] == '중구'

# %%
jgclothes= df[costume&jg]

# %%
jsub=jgclothes.groupby(['업종명']).max('거래금액')['거래금액'].reset_index(name='거래금액')
jsub.sort_values(by='거래금액', ascending = False)
# Out:
#              업종명    거래금액
# 1            귀금속  800000
# 10            신발  800000
# 5           기타직물  600000
# 12            안경  600000
# 14        정장(남성)  500000
# 3           기타의류  500000
# 9             시계  497000
# 4           기타잡화  444000
# 8         스포츠 의류  405650
# 17  카페트.커튼.천막.지물  400000
# 16         침구수예점  375000
# 6           내의판매  300000
# 13          옷감직물  300000
# 0             가방  240000
# 15            제화  222000
# 11          아동의류  215000
# 7           맞춤복점  200000
# 2           기념품점   80000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27134908 entries, 0 to 27134907
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   기준일자       datetime64[ns]
#  1   기준시간대값     int64
#  2   시군구명       category
#  3   카드사명       category
#  4   업종코드       category
#  5   성별코드       category
#  6   거래건수       int64
#  7   총거래금액      int64
#  8   요일         category
#  9   age_range  category
#  10  거래금액       int64
#  11  중분류        category
# dtypes: category(7), datetime64[ns](1), int64(4)
# memory usage: 1.4 GB

# %%
# 가맹점 데이터 로드 후 구별 가맹점 개수 확인
store=pd.read_csv("부산광역시_지역화폐(동백전) 가맹점 현황_20221222.csv", encoding='cp949')

# %%
store['주소']=store['도로명'].fillna(store['지번'])
store=store.drop(['도로명', '지번'], axis=1)

# %%
store['주소'].str.split().str[0].unique()
# Out:
# array(['부산', '부산광역시', '경남', '부산시', '서울', '대구', '충북', '경북', '울산', '경기'],
#       dtype=object)

# %%
store1=store[store['주소'].str.startswith('부산')]

# %%
store1['시군구명']=store1['주소'].str.split().str[1]
# Out:
# /var/folders/h1/rg27m62n4450v9v4ws45x37r0000gn/T/ipykernel_4693/3548469376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store1['시군구명']=store1['주소'].str.split().str[1]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.xticks(rotation=45)
sns.countplot(data=store1, x="시군구명")
# Out:
# <Axes: xlabel='시군구명', ylabel='count'>
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44400 (\N{HANGUL SYLLABLE GUN}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44400 (\N{HANGUL SYLLABLE GUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.
# findfont: Font family 'Malgun Gothic' not found.

# %%
store_count=store1.groupby('시군구명').count()
store_count=store_count.drop(store_count.columns[[1,2,3,4,5]], axis=1)
store_count.columns=['count']
store_count=store_count.sort_values('count', ascending=False)
store_count
# Out:
#       count
# 시군구명
# 부산진구  16031
# 해운대구  13122
# 동래구   10508
# 사하구    9564
# 금정구    8710
# 남구     8243
# 북구     8068
# 사상구    7999
# 수영구    7912
# 연제구    7538
# 기장군    6763
# 강서구    5772
# 중구     5132
# 동구     4991
# 서구     3333
# 영도구    3218

# %% [markdown]
# ### 구별 분석 - 중분류

# %%
# 구별 중분류 행 개수 상위 3개
grouped = df.groupby(['시군구명', '중분류']).size().reset_index(name='count')
top_3 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)
top_3
# 대부분 편의점, 생활, 양식 등 음식이다.
# Out:
#     시군구명     중분류    count
# 0    강서구  편의점/마켓   437872
# 1    강서구      양식   209551
# 2    강서구      생활   209029
# 3    금정구  편의점/마켓   653000
# 4    금정구      생활   377637
# 5    금정구      양식   334352
# 6    기장군  편의점/마켓   321517
# 7    기장군      양식   154930
# 8    기장군      생활   147798
# 9     남구  편의점/마켓   610559
# 10    남구      생활   312161
# 11    남구      양식   280202
# 12    동구  편의점/마켓   231440
# 13    동구      양식   128339
# 14    동구      한식   118957
# 15   동래구  편의점/마켓   795647
# 16   동래구      생활   521643
# 17   동래구      한식   351578
# 18  부산진구  편의점/마켓  1161779
# 19  부산진구      생활   685049
# 20  부산진구      양식   542586
# 21    북구  편의점/마켓   594731
# 22    북구      생활   431020
# 23    북구      양식   251100
# 24   사상구  편의점/마켓   508984
# 25   사상구      생활   244938
# 26   사상구      한식   204065
# 27   사하구  편의점/마켓   651850
# 28   사하구      생활   386290
# 29   사하구      양식   272255
# 30    서구  편의점/마켓   236451
# 31    서구      생활   126524
# 32    서구      양식   122871
# 33   수영구  편의점/마켓   559183
# 34   수영구      생활   276968
# 35   수영구      양식   270800
# 36   연제구  편의점/마켓   625156
# 37   연제구      생활   405814
# 38   연제구      양식   286136
# 39   영도구  편의점/마켓   205884
# 40   영도구      생활   102657
# 41   영도구      한식    85226
# 42    중구  편의점/마켓   188318
# 43    중구      한식   123349
# 44    중구      양식   110002
# 45  해운대구  편의점/마켓   942002
# 46  해운대구      생활   610811
# 47  해운대구      양식   482389

# %%
top_3.to_csv('중분류거래건수top3.csv', index=False)

# %%
# 구별 중분류 평균 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '중분류']).mean('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 연제구를 제외하고는 대부분 전자제품, 교육, 자동차/에너지, 일식이다. 연제구는 문화/취미가 있음 -> 연제구에 부산 서핑? 이런거 있는지 찾아봐도 좋을듯
# Out:
#     시군구명      중분류           거래금액
# 0    강서구     전자제품  243433.575758
# 1    강서구       교육  122102.015553
# 2    강서구  자동차/에너지   52273.230057
# 3    금정구     전자제품  140435.593220
# 4    금정구       교육   98477.247750
# 5    금정구  자동차/에너지   49924.882033
# 6    기장군       교육  135360.881641
# 7    기장군  자동차/에너지   43854.376053
# 8    기장군       일식   42503.522638
# 9     남구       교육  130044.526838
# 10    남구     전자제품   61138.848552
# 11    남구  자동차/에너지   51488.483933
# 12    동구       교육   85756.706514
# 13    동구     전자제품   82148.942308
# 14    동구  자동차/에너지   41531.597611
# 15   동래구       교육  161810.448738
# 16   동래구     전자제품   91284.709906
# 17   동래구       일식   51544.494963
# 18  부산진구       교육  132156.962652
# 19  부산진구     전자제품   87283.228419
# 20  부산진구  자동차/에너지   43836.196820
# 21    북구       교육  134301.800630
# 22    북구     전자제품   96037.040323
# 23    북구  자동차/에너지   49418.894010
# 24   사상구       교육  164068.358372
# 25   사상구       기타   50446.793786
# 26   사상구  자동차/에너지   49945.106658
# 27   사하구       교육  158701.143341
# 28   사하구     전자제품   52565.187713
# 29   사하구  자동차/에너지   47177.739019
# 30    서구       교육  162478.632227
# 31    서구     전자제품  142490.000000
# 32    서구       일식   48857.157303
# 33   수영구       교육  169121.164031
# 34   수영구     전자제품   53750.660750
# 35   수영구       일식   50623.762582
# 36   연제구       교육  172670.874303
# 37   연제구    문화/취미   97038.510634
# 38   연제구  의류/패션잡화   50599.548089
# 39   영도구       교육  171819.237984
# 40   영도구     전자제품   83365.384615
# 41   영도구  자동차/에너지   39797.290476
# 42    중구       교육   52557.173806
# 43    중구     전자제품   50293.141593
# 44    중구       일식   46200.415484
# 45  해운대구     전자제품  326988.797619
# 46  해운대구       교육  172812.622054
# 47  해운대구  자동차/에너지   48752.087944

# %%
top_3.to_csv('중분류거래금액top3.csv', index=False)

# %%
# 구별 중분류 중위수 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '중분류']).median('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 평균과 유사하나 중구에서 의류/패션잡화가 보임. 중구에 옷가게가 많은지 확인 필요. 중위수는 outlier 영향 덜 받아서 평균에서 상위값인데
# 중위수에서는 없는 것들은 높은 금액대 outlier가 있다고 볼 수 있음.
# Out:
#     시군구명      중분류      거래금액
# 0    강서구     전자제품  250000.0
# 1    강서구       교육  100000.0
# 2    강서구  자동차/에너지   50000.0
# 3    금정구     전자제품   76000.0
# 4    금정구  자동차/에너지   50000.0
# 5    금정구       일식   24900.0
# 6    기장군       교육  129000.0
# 7    기장군  자동차/에너지   44852.0
# 8    기장군       일식   34000.0
# 9     남구       교육   90000.0
# 10    남구  자동차/에너지   50000.0
# 11    남구       일식   25500.0
# 12    동구  자동차/에너지   40986.0
# 13    동구     전자제품   34000.0
# 14    동구       일식   24000.0
# 15   동래구       교육  140000.0
# 16   동래구  자동차/에너지   50000.0
# 17   동래구       일식   40000.0
# 18  부산진구       교육   94550.0
# 19  부산진구     전자제품   45000.0
# 20  부산진구  자동차/에너지   40000.0
# 21    북구       교육  120000.0
# 22    북구  자동차/에너지   50000.0
# 23    북구  의류/패션잡화   25000.0
# 24   사상구       교육  140000.0
# 25   사상구  자동차/에너지   50000.0
# 26   사상구       일식   33000.0
# 27   사하구       교육  130000.0
# 28   사하구  자동차/에너지   50000.0
# 29   사하구       일식   33800.0
# 30    서구       교육  140000.0
# 31    서구     전자제품  105750.0
# 32    서구  자동차/에너지   50000.0
# 33   수영구       교육  150000.0
# 34   수영구  자동차/에너지   50000.0
# 35   수영구       일식   34000.0
# 36   연제구       교육  150000.0
# 37   연제구  자동차/에너지   50000.0
# 38   연제구       일식   34500.0
# 39   영도구       교육  160000.0
# 40   영도구  자동차/에너지   30000.0
# 41   영도구       일식   26000.0
# 42    중구       일식   35700.0
# 43    중구  의류/패션잡화   26000.0
# 44    중구       기타   22000.0
# 45  해운대구     전자제품  400000.0
# 46  해운대구       교육  150000.0
# 47  해운대구  자동차/에너지   50000.0

# %%
top_3.to_csv('중분류중위값3.csv', index=False)

# %%
# 구별 중분류 최대 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '중분류']).max('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 그래서 최대값을 확인해 봤는데 의외로 생활, 교육, 뷰티, 레저가 많이 나옴. -> 왜일까,,?
# Out:
#     시군구명      중분류       거래금액
# 0    강서구       생활  1100000.0
# 1    강서구     전자제품  1000000.0
# 2    강서구       교육   960000.0
# 3    금정구       생활  1430000.0
# 4    금정구       레저  1300000.0
# 5    금정구  자동차/에너지  1300000.0
# 6    기장군       교육  1100000.0
# 7    기장군       한식  1007000.0
# 8    기장군       기타  1000000.0
# 9     남구       생활  1470000.0
# 10    남구  의류/패션잡화  1309000.0
# 11    남구       기타  1050000.0
# 12    동구       생활  1970000.0
# 13    동구  의류/패션잡화  1410000.0
# 14    동구       레저   800000.0
# 15   동래구       생활  1300000.0
# 16   동래구       레저  1246500.0
# 17   동래구       교육  1120000.0
# 18  부산진구       교육  1700000.0
# 19  부산진구       생활  1690000.0
# 20  부산진구       기타  1500000.0
# 21    북구  자동차/에너지  1600000.0
# 22    북구       생활  1300000.0
# 23    북구       뷰티  1160000.0
# 24   사상구       생활  1350000.0
# 25   사상구       기타  1050000.0
# 26   사상구       레저  1030000.0
# 27   사하구       뷰티  1400000.0
# 28   사하구       생활  1209800.0
# 29   사하구       교육  1040000.0
# 30    서구       생활  1300000.0
# 31    서구       레저   950000.0
# 32    서구       한식   910000.0
# 33   수영구       생활  1500000.0
# 34   수영구       교육  1020000.0
# 35   수영구       레저   990000.0
# 36   연제구       생활  1700000.0
# 37   연제구    문화/취미  1500000.0
# 38   연제구       레저  1270000.0
# 39   영도구       생활  1000000.0
# 40   영도구       레저   800000.0
# 41   영도구       교육   780000.0
# 42    중구       생활  1100000.0
# 43    중구       뷰티   900000.0
# 44    중구       교육   880000.0
# 45  해운대구       생활  1530000.0
# 46  해운대구    문화/취미  1353000.0
# 47  해운대구     전자제품  1340000.0

# %%
top_3.to_csv('중분류최다거래중위값3.csv', index=False)

# %% [markdown]
# ### 구별 분석 - 기준시간대값

# %%
# 구별 기준시간대값 행 개수 상위 3개
grouped = df.groupby(['시군구명', '기준시간대값']).size().reset_index(name='count')
top_3 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)
top_3
# 대부분 12시, 18시 근처임 아마 밥 시간대라고 예상
# Out:
#     시군구명  기준시간대값   count
# 0    강서구      12  129711
# 1    강서구      18  113918
# 2    강서구      17  111384
# 3    금정구      12  199917
# 4    금정구      18  192374
# 5    금정구      17  174279
# 6    기장군      12   92931
# 7    기장군      18   81716
# 8    기장군      13   80995
# 9     남구      12  178597
# 10    남구      18  160486
# 11    남구      17  148281
# 12    동구      12   91296
# 13    동구      13   59065
# 14    동구      18   55035
# 15   동래구      18  224681
# 16   동래구      12  217807
# 17   동래구      17  206973
# 18  부산진구      12  335528
# 19  부산진구      18  304662
# 20  부산진구      17  282429
# 21    북구      12  175550
# 22    북구      18  175546
# 23    북구      17  166406
# 24   사상구      12  141497
# 25   사상구      18  123968
# 26   사상구      17  114473
# 27   사하구      12  178015
# 28   사하구      18  177233
# 29   사하구      17  164931
# 30    서구      12   73207
# 31    서구      18   54009
# 32    서구      13   53826
# 33   수영구      12  141904
# 34   수영구      18  137209
# 35   수영구      19  125854
# 36   연제구      12  194696
# 37   연제구      18  165438
# 38   연제구      17  147150
# 39   영도구      12   63779
# 40   영도구      18   49340
# 41   영도구      17   45704
# 42    중구      12   84145
# 43    중구      13   57398
# 44    중구      18   52295
# 45  해운대구      12  295642
# 46  해운대구      18  249615
# 47  해운대구      13  242192

# %%
top_3.to_csv('거래시간상위3.csv', index=False)

# %%
# 구별 기준시간대값 평균 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '기준시간대값']).mean('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 대부분 20시, 19시로 저녁시간대라 술 혹은 회식 정도로 예상 하지만 15시가 있는데 이유를 모르겠음, 학원? 여가?
# Out:
#     시군구명  기준시간대값          거래금액
# 0    강서구      20  26185.431816
# 1    강서구      19  26176.975256
# 2    강서구      15  25589.950973
# 3    금정구      19  22345.085592
# 4    금정구      20  22077.104567
# 5    금정구      16  20717.653643
# 6    기장군      19  27088.700846
# 7    기장군      18  26891.715368
# 8    기장군      20  25946.912248
# 9     남구      20  22959.251863
# 10    남구      19  22806.800905
# 11    남구      18  21292.310781
# 12    동구      20  22515.804847
# 13    동구      19  21833.840837
# 14    동구      15  19992.047018
# 15   동래구      20  26052.149949
# 16   동래구      19  25576.031450
# 17   동래구      15  24236.289950
# 18  부산진구      20  24014.418200
# 19  부산진구      19  23454.441002
# 20  부산진구      15  22885.488053
# 21    북구      20  24043.170297
# 22    북구      19  23796.330945
# 23    북구      15  22711.366678
# 24   사상구      20  24046.082371
# 25   사상구      19  23426.835786
# 26   사상구      16  22343.079239
# 27   사하구      20  24047.159964
# 28   사하구      19  24045.866305
# 29   사하구      18  22065.899071
# 30    서구      19  22346.649658
# 31    서구      20  22008.934360
# 32    서구      15  20438.812776
# 33   수영구      20  25154.593151
# 34   수영구      19  24697.444753
# 35   수영구      21  23203.391382
# 36   연제구      20  25674.769376
# 37   연제구      19  24430.825217
# 38   연제구      15  22503.320688
# 39   영도구      20  23022.971495
# 40   영도구      19  22836.825650
# 41   영도구      18  19596.573774
# 42    중구      20  29377.548218
# 43    중구      19  27879.598062
# 44    중구      21  26020.036959
# 45  해운대구      19  25912.803100
# 46  해운대구      20  25820.680222
# 47  해운대구      15  25051.856638

# %%
top_3.to_csv('시간별평균거래금액top3.csv', index=False)

# %%
# 구별 기준시간대값 중위수 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '기준시간대값']).median('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 중위수로 보면 대부분 19시 근처 12시 정도인 걸로 봐서 식사로 예상됨, 아마 20시에는 간혹가다 비싸게 먹는 경우가 좀 있는듯.
# 또한 15시에는 아마 놀거리가 있을 수 있음.(비싼 체험 같은것?)
# Out:
#     시군구명  기준시간대값     거래금액
# 0    강서구      19  13410.0
# 1    강서구      20  12450.0
# 2    강서구      18  12240.0
# 3    금정구      19  10490.0
# 4    금정구      20   9500.0
# 5    금정구      18   9390.0
# 6    기장군      19  14420.0
# 7    기장군      18  13450.0
# 8    기장군      13  13000.0
# 9     남구      19  10600.0
# 10    남구      18  10000.0
# 11    남구      20  10000.0
# 12    동구      19  10000.0
# 13    동구      20   9860.0
# 14    동구      18   9000.0
# 15   동래구      19  11030.0
# 16   동래구      20  10400.0
# 17   동래구      18  10000.0
# 18  부산진구      19  10800.0
# 19  부산진구      20  10200.0
# 20  부산진구      18   9500.0
# 21    북구      19  11000.0
# 22    북구      18  10000.0
# 23    북구      20  10000.0
# 24   사상구      19  11480.0
# 25   사상구      20  10800.0
# 26   사상구      18  10000.0
# 27   사하구      19  11200.0
# 28   사하구      20  10230.0
# 29   사하구      18  10000.0
# 30    서구      19  10000.0
# 31    서구      18   9000.0
# 32    서구      20   9000.0
# 33   수영구      19  10900.0
# 34   수영구      20  10050.0
# 35   수영구      18   9800.0
# 36   연제구      19  10300.0
# 37   연제구      20   9900.0
# 38   연제구      12   9000.0
# 39   영도구      19  11900.0
# 40   영도구      20  10300.0
# 41   영도구      13  10000.0
# 42    중구      19  15000.0
# 43    중구      20  14000.0
# 44    중구      21  11100.0
# 45  해운대구      19  11000.0
# 46  해운대구      18  10000.0
# 47  해운대구      20  10000.0

# %%
top_3.to_csv('시간별중위값거래금액top3.csv', index=False)

# %%
# 구별 기준시간대값 최대 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '기준시간대값']).max('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 특별한 경향성은 보이지 않고 골고루 나온듯, 하지만 유사한 구들이 몇몇 보임 clustering 하면 뭔가 나올지도?
# Out:
#     시군구명  기준시간대값     거래금액
# 0    강서구      18  1100000
# 1    강서구      11  1000000
# 2    강서구      16  1000000
# 3    금정구      18  1430000
# 4    금정구      14  1300000
# 5    금정구      20  1300000
# 6    기장군      15  1100000
# 7    기장군      13  1007000
# 8    기장군       9  1000000
# 9     남구      15  1470000
# 10    남구      10  1400000
# 11    남구      14  1309000
# 12    동구       9  1970000
# 13    동구      16  1410000
# 14    동구      10  1400000
# 15   동래구       9  1300000
# 16   동래구      13  1246500
# 17   동래구      10  1200000
# 18  부산진구      17  1700000
# 19  부산진구      18  1690000
# 20  부산진구      11  1580000
# 21    북구      11  1600000
# 22    북구      16  1300000
# 23    북구      18  1200000
# 24   사상구      17  1350000
# 25   사상구      12  1220000
# 26   사상구      11  1100000
# 27   사하구      19  1400000
# 28   사하구      14  1209800
# 29   사하구      16  1193441
# 30    서구      15  1300000
# 31    서구      10  1000000
# 32    서구      11  1000000
# 33   수영구       9  1500000
# 34   수영구      11  1200000
# 35   수영구      15  1200000
# 36   연제구      16  1700000
# 37   연제구      11  1500000
# 38   연제구      13  1500000
# 39   영도구      10  1000000
# 40   영도구      17   800000
# 41   영도구      14   780000
# 42    중구      10  1100000
# 43    중구      14  1100000
# 44    중구      16  1030000
# 45  해운대구      10  1530000
# 46  해운대구      12  1500000
# 47  해운대구      17  1500000

# %%
top_3.to_csv('시간별거래금액top3.csv', index=False)

# %% [markdown]
# ### 구별 분석 - 요일

# %%
# 구별 요일 행 개수 상위 3개
grouped = df.groupby(['시군구명', '요일']).size().reset_index(name='count')
top_3 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)
top_3
# 금, 토, 수가 가장 많이 나오는데 수요일은 6,7,8 월에 요일개수가 가장 많아서 그런것 같음.
# Out:
#     시군구명         요일   count
# 0    강서구     Friday  210850
# 1    강서구  Wednesday  206584
# 2    강서구   Saturday  199202
# 3    금정구     Friday  335469
# 4    금정구  Wednesday  330052
# 5    금정구   Saturday  328765
# 6    기장군   Saturday  154399
# 7    기장군     Friday  146754
# 8    기장군  Wednesday  141052
# 9     남구     Friday  295027
# 10    남구  Wednesday  289065
# 11    남구   Saturday  283007
# 12    동구     Friday  120828
# 13    동구  Wednesday  115003
# 14    동구   Thursday  113611
# 15   동래구     Friday  395681
# 16   동래구   Saturday  391054
# 17   동래구  Wednesday  380992
# 18  부산진구     Friday  567590
# 19  부산진구   Saturday  550158
# 20  부산진구  Wednesday  549205
# 21    북구     Friday  313578
# 22    북구   Saturday  312835
# 23    북구  Wednesday  304969
# 24   사상구     Friday  238108
# 25   사상구  Wednesday  230537
# 26   사상구   Saturday  226946
# 27   사하구     Friday  318331
# 28   사하구   Saturday  310115
# 29   사하구  Wednesday  307872
# 30    서구  Wednesday  109478
# 31    서구     Friday  108827
# 32    서구   Thursday  105527
# 33   수영구   Saturday  256183
# 34   수영구     Friday  248978
# 35   수영구  Wednesday  241263
# 36   연제구     Friday  307590
# 37   연제구  Wednesday  299034
# 38   연제구   Thursday  288574
# 39   영도구   Saturday   90627
# 40   영도구     Friday   90078
# 41   영도구  Wednesday   88969
# 42    중구     Friday  105785
# 43    중구  Wednesday  101373
# 44    중구   Saturday   99500
# 45  해운대구     Friday  481200
# 46  해운대구   Saturday  475913
# 47  해운대구  Wednesday  470677

# %%
# 구별 요일 평균 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '요일']).mean('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 대부분 목,금,토,일임 금토일은 주말이니까 아무래도 외식, 여행, 여가에서 돈을 많이 쓴 것으로 예상.
# 목요일은 회식? 아니면 금요일 휴가내고 돈을 많이 썼다고 볼 수도 있음 6,7,8이면 여름 휴가가 있는 계절
# 서구에서 화요일이 2위인데 이건 이유를 모르겠음 우연인듯?
# Out:
#     시군구명        요일          거래금액
# 0    강서구    Friday  23510.367346
# 1    강서구  Saturday  23388.850559
# 2    강서구    Monday  22479.443313
# 3    금정구  Saturday  20244.739574
# 4    금정구    Friday  19726.745974
# 5    금정구    Sunday  18507.906182
# 6    기장군  Saturday  24885.533002
# 7    기장군    Sunday  24134.276023
# 8    기장군    Friday  23742.134211
# 9     남구  Saturday  20967.045137
# 10    남구    Friday  19989.425070
# 11    남구   Tuesday  19180.472043
# 12    동구  Saturday  20255.871483
# 13    동구    Friday  18203.602153
# 14    동구    Sunday  17580.935148
# 15   동래구    Friday  23453.153027
# 16   동래구  Saturday  22977.822756
# 17   동래구  Thursday  22503.175795
# 18  부산진구  Saturday  22210.354191
# 19  부산진구    Friday  21362.400564
# 20  부산진구  Thursday  20246.623309
# 21    북구    Friday  21718.351530
# 22    북구  Saturday  21509.081714
# 23    북구  Thursday  20763.268716
# 24   사상구  Saturday  22393.728477
# 25   사상구    Friday  21093.972315
# 26   사상구    Sunday  20677.278695
# 27   사하구    Friday  21259.783317
# 28   사하구  Saturday  21085.078042
# 29   사하구  Thursday  20237.694339
# 30    서구  Saturday  19096.753669
# 31    서구   Tuesday  18854.433135
# 32    서구    Friday  18778.565779
# 33   수영구  Saturday  22927.772713
# 34   수영구    Friday  21871.164079
# 35   수영구  Thursday  20820.302158
# 36   연제구  Saturday  22720.239153
# 37   연제구    Friday  21354.623073
# 38   연제구  Thursday  20270.777960
# 39   영도구  Saturday  18883.164752
# 40   영도구    Sunday  18075.131597
# 41   영도구    Friday  17874.182464
# 42    중구  Saturday  24871.483899
# 43    중구    Sunday  21914.249542
# 44    중구    Friday  21338.180659
# 45  해운대구  Saturday  23651.522112
# 46  해운대구    Friday  22967.606536
# 47  해운대구  Thursday  22031.817604

# %%
top_3.to_csv('요일별평균거래금액top3.csv', index=False)

# %%
# 구별 요일 중위수 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '요일']).median('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 서구에서 화요일이 없어진 것으로 보아 화요일에 outlier가 몇개 있었는 듯
# Out:
#     시군구명        요일     거래금액
# 0    강서구    Sunday  11600.0
# 1    강서구  Saturday  11100.0
# 2    강서구    Friday   9800.0
# 3    금정구  Saturday   9000.0
# 4    금정구    Sunday   8700.0
# 5    금정구    Friday   8000.0
# 6    기장군    Sunday  12500.0
# 7    기장군  Saturday  12000.0
# 8    기장군    Friday  10000.0
# 9     남구  Saturday   9080.0
# 10    남구    Sunday   9000.0
# 11    남구    Friday   8000.0
# 12    동구  Saturday   9000.0
# 13    동구    Sunday   8500.0
# 14    동구    Friday   7900.0
# 15   동래구  Saturday   9400.0
# 16   동래구    Sunday   9000.0
# 17   동래구    Friday   8600.0
# 18  부산진구  Saturday   9300.0
# 19  부산진구    Sunday   8900.0
# 20  부산진구    Friday   8400.0
# 21    북구  Saturday   9681.0
# 22    북구    Sunday   9500.0
# 23    북구    Friday   8868.0
# 24   사상구  Saturday  10220.0
# 25   사상구    Sunday  10000.0
# 26   사상구    Friday   9000.0
# 27   사하구  Saturday   9090.0
# 28   사하구    Sunday   9000.0
# 29   사하구    Friday   8500.0
# 30    서구  Saturday   8500.0
# 31    서구    Sunday   8000.0
# 32    서구    Friday   7725.0
# 33   수영구  Saturday   9600.0
# 34   수영구    Sunday   9000.0
# 35   수영구    Friday   8700.0
# 36   연제구  Saturday   9000.0
# 37   연제구    Sunday   8400.0
# 38   연제구    Friday   8000.0
# 39   영도구    Sunday   9700.0
# 40   영도구  Saturday   9600.0
# 41   영도구    Friday   8500.0
# 42    중구  Saturday  11600.0
# 43    중구    Sunday  11000.0
# 44    중구    Friday   9000.0
# 45  해운대구  Saturday   9500.0
# 46  해운대구    Sunday   9000.0
# 47  해운대구    Friday   8500.0

# %%
top_3.to_csv('요일별중위값거래금액top3.csv', index=False)

# %%
# 구별 요일 최대 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '요일']).max('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 보통 금 혹은 토가 포함돼 있고 나머지는 골고루 있다.
# 예상과 달리 서구에서 화요일이 포함되지 않은 것을 보아 한번 확인해볼 필요가 있어보임.
# Out:
#     시군구명         요일     거래금액
# 0    강서구     Friday  1100000
# 1    강서구     Monday  1000000
# 2    강서구  Wednesday  1000000
# 3    금정구     Friday  1430000
# 4    금정구   Thursday  1300000
# 5    금정구    Tuesday  1200000
# 6    기장군   Thursday  1100000
# 7    기장군     Sunday  1007000
# 8    기장군     Friday  1000000
# 9     남구    Tuesday  1470000
# 10    남구   Saturday  1400000
# 11    남구   Thursday  1309000
# 12    동구     Monday  1970000
# 13    동구   Saturday  1410000
# 14    동구    Tuesday  1377400
# 15   동래구     Friday  1300000
# 16   동래구    Tuesday  1246500
# 17   동래구   Thursday  1230000
# 18  부산진구     Friday  1700000
# 19  부산진구     Monday  1690000
# 20  부산진구   Saturday  1500000
# 21    북구     Friday  1600000
# 22    북구   Thursday  1300000
# 23    북구   Saturday  1220000
# 24   사상구     Friday  1350000
# 25   사상구   Saturday  1100000
# 26   사상구     Monday  1050000
# 27   사하구     Monday  1400000
# 28   사하구  Wednesday  1209800
# 29   사하구    Tuesday  1193441
# 30    서구     Friday  1300000
# 31    서구   Saturday  1000000
# 32    서구  Wednesday  1000000
# 33   수영구   Saturday  1500000
# 34   수영구   Thursday  1200000
# 35   수영구  Wednesday  1200000
# 36   연제구     Monday  1700000
# 37   연제구   Saturday  1500000
# 38   연제구  Wednesday  1400000
# 39   영도구    Tuesday  1000000
# 40   영도구     Monday   800000
# 41   영도구  Wednesday   800000
# 42    중구     Monday  1100000
# 43    중구  Wednesday  1100000
# 44    중구   Thursday  1030000
# 45  해운대구     Friday  1530000
# 46  해운대구   Saturday  1500000
# 47  해운대구    Tuesday  1460000

# %%
top_3.to_csv('요일별최다거래top3.csv', index=False)

# %% [markdown]
# ### 구별 분석 - 나이대

# %%
# 구별 나이대 행 개수 상위 3개
grouped = df.groupby(['시군구명', 'age_range']).size().reset_index(name='count')
top_3 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)
top_3
# 30,40,50대가 가장 많이 사용, 당연히 사회인들이라 지출이 많을 것으로 예상. 하지만 금정구에서만 20대가 1위인데 금정구가 20대들 핫플인지
# 알아볼 필요가 있어보임.
# Out:
#     시군구명 age_range   count
# 0    강서구        40  473223
# 1    강서구        30  381647
# 2    강서구        50  214758
# 3    금정구        20  446845
# 4    금정구        50  442071
# 5    금정구        40  440800
# 6    기장군        40  312514
# 7    기장군        30  204543
# 8    기장군        50  196883
# 9     남구        40  450062
# 10    남구        50  397861
# 11    남구        30  339177
# 12    동구        30  176406
# 13    동구        40  162036
# 14    동구        50  153786
# 15   동래구        40  641396
# 16   동래구        50  551630
# 17   동래구        30  482152
# 18  부산진구        30  799624
# 19  부산진구        40  762544
# 20  부산진구        50  695036
# 21    북구        40  473215
# 22    북구        50  448885
# 23    북구        30  402780
# 24   사상구        40  338186
# 25   사상구        50  326300
# 26   사상구        30  310729
# 27   사하구        40  484307
# 28   사하구        50  448589
# 29   사하구        30  385508
# 30    서구        40  161955
# 31    서구        50  148579
# 32    서구        30  136209
# 33   수영구        30  359230
# 34   수영구        40  341084
# 35   수영구        50  319161
# 36   연제구        40  486113
# 37   연제구        50  426234
# 38   연제구        30  401849
# 39   영도구        40  137186
# 40   영도구        50  133674
# 41   영도구        30  104816
# 42    중구        30  149392
# 43    중구        40  138435
# 44    중구        50  130959
# 45  해운대구        40  778916
# 46  해운대구        50  698286
# 47  해운대구        30  619444

# %%
top_3.to_csv('나이대별top3.csv', index=False)

# %%
# 구별 나이대 평균 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', 'age_range']).mean('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 10대, 40대, 90대 등 의외로 좀 퍼져있음. 30,50대는 거의 없는 것으로 보아 많이 사용하지만 높은 금액을 사용하지는 않는듯 함.
# 40대에 지출이 많은데 아마 자식 혹은 수입이 많아서로 예상, 10대는 교육 90대는 여가 혹은 병원으로 예상.
# Out:
#     시군구명 age_range          거래금액
# 0    강서구        10  27465.078912
# 1    강서구        70  24983.695449
# 2    강서구        40  24734.278347
# 3    금정구        10  25864.527815
# 4    금정구        90  22734.148410
# 5    금정구        40  22480.540052
# 6    기장군        90  32426.942857
# 7    기장군        70  26586.273904
# 8    기장군        60  25966.698793
# 9     남구        90  23589.407216
# 10    남구        40  22448.129962
# 11    남구        80  21625.477998
# 12    동구       100  75000.000000
# 13    동구        70  25033.996691
# 14    동구        80  23778.455544
# 15   동래구        10  31752.533202
# 16   동래구        40  26678.522018
# 17   동래구        80  23267.719777
# 18  부산진구        10  27122.852422
# 19  부산진구        90  24413.035124
# 20  부산진구        70  22441.446172
# 21    북구        90  37945.289655
# 22    북구        10  26155.933989
# 23    북구        40  23483.479184
# 24   사상구        10  25274.681812
# 25   사상구        60  23416.366947
# 26   사상구        80  23312.723439
# 27   사하구       100  36350.000000
# 28   사하구        10  29023.678088
# 29   사하구        40  23434.280221
# 30    서구        70  24185.306745
# 31    서구        80  23953.190856
# 32    서구        10  23696.738189
# 33   수영구        10  30342.246612
# 34   수영구        40  24061.107396
# 35   수영구        80  23645.303584
# 36   연제구        10  33962.574846
# 37   연제구        90  25882.785294
# 38   연제구        40  22705.903049
# 39   영도구       100  28425.000000
# 40   영도구        10  25199.610616
# 41   영도구        70  19999.117395
# 42    중구        90  30869.595960
# 43    중구        70  26696.063471
# 44    중구        80  26081.677839
# 45  해운대구        10  30145.799367
# 46  해운대구        40  25491.423390
# 47  해운대구        80  23990.198642

# %%
top_3.to_csv('나이대별평균거래금액top3.csv', index=False)

# %%
# 구별 나이대 중위수 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', 'age_range']).median('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 중위수로 봤을 때 60대 이상인 것으로 보아 지출이 병원쪽으로 나가서 높게 측정된 것으로 생각된다.
# Out:
#     시군구명 age_range     거래금액
# 0    강서구        70  12300.0
# 1    강서구        60  12000.0
# 2    강서구        80  12000.0
# 3    금정구        90  12460.0
# 4    금정구        60  10000.0
# 5    금정구        70  10000.0
# 6    기장군        60  13460.0
# 7    기장군        70  13000.0
# 8    기장군        80  12940.0
# 9     남구        80  10200.0
# 10    남구        60  10000.0
# 11    남구        70  10000.0
# 12    동구       100  75000.0
# 13    동구        80  11310.0
# 14    동구        70  11200.0
# 15   동래구        60  10000.0
# 16   동래구        70  10000.0
# 17   동래구        80  10000.0
# 18  부산진구       100  14000.0
# 19  부산진구        90  10500.0
# 20  부산진구        80  10458.0
# 21    북구        90  16000.0
# 22    북구        50  10000.0
# 23    북구        60  10000.0
# 24   사상구        60  11100.0
# 25   사상구        70  11000.0
# 26   사상구        50  10000.0
# 27   사하구       100  36350.0
# 28   사하구        60   9950.0
# 29   사하구        70   9600.0
# 30    서구        70  10000.0
# 31    서구        80  10000.0
# 32    서구        60   9900.0
# 33   수영구        60  10000.0
# 34   수영구        70  10000.0
# 35   수영구        80  10000.0
# 36   연제구        90  11530.0
# 37   연제구        80  10000.0
# 38   연제구        60   9600.0
# 39   영도구       100  28425.0
# 40   영도구        60  10000.0
# 41   영도구        70  10000.0
# 42    중구        90  18000.0
# 43    중구        80  13200.0
# 44    중구        70  13000.0
# 45  해운대구        80  11000.0
# 46  해운대구        60  10000.0
# 47  해운대구        70  10000.0

# %%
top_3.to_csv('나이대별중위값거래금액top3.csv', index=False)

# %%
# 구별 나이대 최대 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', 'age_range']).max('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 대부분 돈이 많은 시기인 30~60대 사이임. 간혹 20대가 있는데 젊은 나이에 돈을 많이 벌었거나 금수저인듯.
# Out:
#     시군구명 age_range       거래금액
# 0    강서구        40  1100000.0
# 1    강서구        30  1000000.0
# 2    강서구        50   960000.0
# 3    금정구        50  1430000.0
# 4    금정구        70  1300000.0
# 5    금정구        40  1200000.0
# 6    기장군        40  1100000.0
# 7    기장군        60  1007000.0
# 8    기장군        30  1000000.0
# 9     남구        40  1470000.0
# 10    남구        60  1400000.0
# 11    남구        30  1309000.0
# 12    동구        30  1970000.0
# 13    동구        50  1377400.0
# 14    동구        20  1070000.0
# 15   동래구        60  1300000.0
# 16   동래구        30  1246500.0
# 17   동래구        40  1200000.0
# 18  부산진구        40  1700000.0
# 19  부산진구        50  1580000.0
# 20  부산진구        20  1500000.0
# 21    북구        40  1600000.0
# 22    북구        60  1300000.0
# 23    북구        50  1200000.0
# 24   사상구        60  1350000.0
# 25   사상구        40  1220000.0
# 26   사상구        30  1050000.0
# 27   사하구        50  1400000.0
# 28   사하구        30  1209800.0
# 29   사하구        60  1193441.0
# 30    서구        30  1300000.0
# 31    서구        40  1000000.0
# 32    서구        60  1000000.0
# 33   수영구        60  1500000.0
# 34   수영구        40  1200000.0
# 35   수영구        50  1200000.0
# 36   연제구        40  1700000.0
# 37   연제구        30  1500000.0
# 38   연제구        60  1500000.0
# 39   영도구        40  1000000.0
# 40   영도구        60   800000.0
# 41   영도구        30   680400.0
# 42    중구        40  1100000.0
# 43    중구        50  1100000.0
# 44    중구        80  1000000.0
# 45  해운대구        50  1530000.0
# 46  해운대구        40  1500000.0
# 47  해운대구        60  1500000.0

# %%
top_3.to_csv('나이대별최다거래금액top3.csv', index=False)

# %% [markdown]
# ### 구별 분석 - 성별

# %%
# 구별 성별 행 개수 상위 2개
grouped = df.groupby(['시군구명', '성별코드']).size().reset_index(name='count')
top_2 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(2, 'count')).reset_index(drop=True)
top_2
# 대부분 여자가 높음
# Out:
# /var/folders/h1/rg27m62n4450v9v4ws45x37r0000gn/T/ipykernel_4693/4085547729.py:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   top_2 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(2, 'count')).reset_index(drop=True)
#     시군구명 성별코드    count
# 0    강서구    F   685329
# 1    강서구    M   650782
# 2    금정구    F  1161455
# 3    금정구    M   989976
# 4    기장군    F   511194
# 5    기장군    M   452487
# 6     남구    F  1008887
# 7     남구    M   872620
# 8     동구    F   377939
# 9     동구    M   348452
# 10   동래구    F  1412092
# 11   동래구    M  1092853
# 12  부산진구    F  2026673
# 13  부산진구    M  1541805
# 14    북구    F  1132701
# 15    북구    M   862918
# 16   사상구    F   767423
# 17   사상구    M   722007
# 18   사하구    F  1100408
# 19   사하구    M   904472
# 20    서구    F   382651
# 21    서구    M   308872
# 22   수영구    F   892088
# 23   수영구    M   703486
# 24   연제구    F  1054100
# 25   연제구    M   857935
# 26   영도구    F   316321
# 27   영도구    M   266108
# 28    중구    F   365880
# 29    중구    M   289810
# 30  해운대구    F  1716834
# 31  해운대구    M  1358350

# %%
top_2.to_csv('구별남녀거래수.csv', index=False)

# %%
# 구별 성별 평균 건당 거래금액 상위 2개
grouped=df.groupby(['시군구명', '성별코드']).mean('거래금액')['거래금액'].reset_index(name='거래금액')
top_2=grouped.groupby('시군구명').apply(lambda x: x.nlargest(2, '거래금액')).reset_index(drop=True)
top_2
# 북구와 사상구를 제외하고는 여자가 높음. 북구와 사상구에서 차이가 크지는 않지만 알아볼 필요는 있을 듯. 회사가 많다던가, 남자들이 주로
# 이용하는 가게가 많다던가 등등
# Out:
#     시군구명 성별코드          거래금액
# 0    강서구    F  22989.975183
# 1    강서구    M  22247.768463
# 2    금정구    F  19367.257261
# 3    금정구    M  18215.996945
# 4    기장군    F  23723.610306
# 5    기장군    M  23012.733935
# 6     남구    F  19899.644112
# 7     남구    M  18810.405176
# 8     동구    F  18132.774329
# 9     동구    M  17461.214176
# 10   동래구    F  22287.222619
# 11   동래구    M  22003.316141
# 12  부산진구    F  21046.273851
# 13  부산진구    M  19500.022546
# 14    북구    M  20837.301727
# 15    북구    F  20701.169265
# 16   사상구    M  20884.872472
# 17   사상구    F  20424.479066
# 18   사하구    F  20434.083837
# 19   사하구    M  19988.114112
# 20    서구    F  18776.872338
# 21    서구    M  17902.977602
# 22   수영구    F  21355.181253
# 23   수영구    M  20624.369894
# 24   연제구    F  20729.509518
# 25   연제구    M  20166.676197
# 26   영도구    F  18218.690662
# 27   영도구    M  16882.273318
# 28    중구    F  21601.124563
# 29    중구    M  20167.132318
# 30  해운대구    F  22585.117458
# 31  해운대구    M  21667.572563

# %%
top_2.to_csv('구별남녀평균거래금액.csv', index=False)

# %%
# 구별 성별 중위수 건당 거래금액 상위 2개
grouped=df.groupby(['시군구명', '성별코드']).median('거래금액')['거래금액'].reset_index(name='거래금액')
top_2=grouped.groupby('시군구명').apply(lambda x: x.nlargest(2, '거래금액')).reset_index(drop=True)
top_2
# 동구에서 남자가 높은 것으로 보아 동구에서는 남자가 금액을 높게 사용하지만 여자 중에 outlier로 많이 사용하는 경우가 몇몇 있는듯.
# 북구와 사상구에서 여자가 높은 것으로 보아 outlier 남자가 몇몇 있는 듯. 혹은 남자들이 돈을 많이 쓸법한 장소가 있다고도 생각 가능.
# Out:
#     시군구명 성별코드     거래금액
# 0    강서구    F  10000.0
# 1    강서구    M   9000.0
# 2    금정구    F   8000.0
# 3    금정구    M   7380.0
# 4    기장군    F  10800.0
# 5    기장군    M  10000.0
# 6     남구    F   8450.0
# 7     남구    M   8000.0
# 8     동구    M   8000.0
# 9     동구    F   7900.0
# 10   동래구    F   8600.0
# 11   동래구    M   8350.0
# 12  부산진구    F   8690.0
# 13  부산진구    M   8000.0
# 14    북구    F   8800.0
# 15    북구    M   8700.0
# 16   사상구    F   9000.0
# 17   사상구    M   9000.0
# 18   사하구    F   8500.0
# 19   사하구    M   8275.0
# 20    서구    F   7700.0
# 21    서구    M   7600.0
# 22   수영구    F   9000.0
# 23   수영구    M   8150.0
# 24   연제구    F   8000.0
# 25   연제구    M   8000.0
# 26   영도구    F   8960.0
# 27   영도구    M   8200.0
# 28    중구    F  10000.0
# 29    중구    M   8700.0
# 30  해운대구    F   8750.0
# 31  해운대구    M   8100.0

# %%
top_2.to_csv('구별남녀중위거래금액.csv', index=False)

# %%
# 구별 성별 최대 건당 거래금액 상위 2개
grouped=df.groupby(['시군구명', '성별코드']).max('거래금액')['거래금액'].reset_index(name='거래금액')
top_2=grouped.groupby('시군구명').apply(lambda x: x.nlargest(2, '거래금액')).reset_index(drop=True)
top_2
# 남구, 서구, 수영구, 영도구 제외 여자가 높음 하지만 이것은 최대값이라 큰 상관은 없을듯.
# Out:
#     시군구명 성별코드     거래금액
# 0    강서구    F  1100000
# 1    강서구    M  1000000
# 2    금정구    F  1430000
# 3    금정구    M  1300000
# 4    기장군    F  1100000
# 5    기장군    M  1000000
# 6     남구    M  1470000
# 7     남구    F  1400000
# 8     동구    F  1970000
# 9     동구    M  1410000
# 10   동래구    F  1300000
# 11   동래구    M  1246500
# 12  부산진구    F  1700000
# 13  부산진구    M  1580000
# 14    북구    F  1600000
# 15    북구    M  1220000
# 16   사상구    F  1350000
# 17   사상구    M  1100000
# 18   사하구    F  1400000
# 19   사하구    M  1076600
# 20    서구    M  1300000
# 21    서구    F  1000000
# 22   수영구    M  1500000
# 23   수영구    F  1200000
# 24   연제구    F  1700000
# 25   연제구    M  1500000
# 26   영도구    M  1000000
# 27   영도구    F   800000
# 28    중구    F  1100000
# 29    중구    M  1100000
# 30  해운대구    M  1530000
# 31  해운대구    F  1500000

# %%
top_2.to_csv('구별남녀평균거래금액.csv', index=False)

# %% [markdown]
# ### 구별 분석 - 카드사

# %%
# 구별 카드사 행 개수 상위 3개
grouped = df.groupby(['시군구명', '카드사명']).size().reset_index(name='count')
top_3 = grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)
top_3
# 전부 코나, 하나, 부산 순으로 특이점은 없었음.
# Out:
#     시군구명 카드사명    count
# 0    강서구   코나   690809
# 1    강서구   하나   385688
# 2    강서구   부산   232309
# 3    금정구   코나  1157285
# 4    금정구   하나   521419
# 5    금정구   부산   423142
# 6    기장군   코나   514232
# 7    기장군   하나   266323
# 8    기장군   부산   157888
# 9     남구   코나  1018620
# 10    남구   하나   459141
# 11    남구   부산   369170
# 12    동구   코나   392745
# 13    동구   하나   176643
# 14    동구   부산   147609
# 15   동래구   코나  1297111
# 16   동래구   하나   643736
# 17   동래구   부산   518011
# 18  부산진구   코나  1885143
# 19  부산진구   하나   892965
# 20  부산진구   부산   733357
# 21    북구   코나  1088470
# 22    북구   하나   500760
# 23    북구   부산   361174
# 24   사상구   코나   808216
# 25   사상구   하나   349486
# 26   사상구   부산   298510
# 27   사하구   코나  1109956
# 28   사하구   하나   447824
# 29   사하구   부산   408393
# 30    서구   코나   370984
# 31    서구   하나   164683
# 32    서구   부산   144777
# 33   수영구   코나   859011
# 34   수영구   하나   391522
# 35   수영구   부산   319970
# 36   연제구   코나   980185
# 37   연제구   하나   497320
# 38   연제구   부산   401455
# 39   영도구   코나   317034
# 40   영도구   하나   130912
# 41   영도구   부산   121593
# 42    중구   코나   357534
# 43    중구   하나   156902
# 44    중구   부산   133189
# 45  해운대구   코나  1627364
# 46  해운대구   하나   795569
# 47  해운대구   부산   588080

# %%
# 구별 카드사 평균 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '카드사명']).mean('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 대부분 QR, 코나, 하나 순이지만 종종 농협이 껴있음. 중구에는 농협대신 부산이 있음.
# QR로 어떤 것을 계산하는지 알아볼 필요가 있음. 농협이 있는 곳에 주거지구인지를 알아볼 필요 있음(장보는데 사용)
# 중구에는 왜 부산을 많이 사용했을지 생각.
# Out:
#     시군구명 카드사명           거래금액
# 0    강서구   QR  151907.021708
# 1    강서구   코나   23140.102856
# 2    강서구   농협   22177.615365
# 3    금정구   QR   65671.444444
# 4    금정구   코나   19103.123242
# 5    금정구   하나   19031.974147
# 6    기장군   QR  162071.387189
# 7    기장군   코나   23686.290384
# 8    기장군   하나   22735.440792
# 9     남구   QR   66682.484444
# 10    남구   코나   19840.263158
# 11    남구   하나   19517.038840
# 12    동구   QR   62545.750000
# 13    동구   코나   18179.657531
# 14    동구   농협   17572.624868
# 15   동래구   QR   77406.847946
# 16   동래구   코나   22647.327604
# 17   동래구   하나   22230.465138
# 18  부산진구   QR   79206.735198
# 19  부산진구   코나   20749.974676
# 20  부산진구   하나   20454.267559
# 21    북구   QR   65962.773275
# 22    북구   코나   21368.475733
# 23    북구   하나   20276.841629
# 24   사상구   QR   89462.305882
# 25   사상구   코나   21108.341004
# 26   사상구   하나   20951.841233
# 27   사하구   QR  115282.445983
# 28   사하구   코나   20626.118782
# 29   사하구   하나   20290.342291
# 30    서구   QR   57608.308108
# 31    서구   코나   18771.730139
# 32    서구   하나   17948.551326
# 33   수영구   QR   60309.026316
# 34   수영구   코나   21309.600863
# 35   수영구   하나   21260.785941
# 36   연제구   QR  110966.721852
# 37   연제구   농협   20961.073555
# 38   연제구   코나   20942.654407
# 39   영도구   QR   64970.449309
# 40   영도구   코나   17797.537923
# 41   영도구   하나   17692.782327
# 42    중구   QR   39968.613687
# 43    중구   코나   21287.705175
# 44    중구   부산   20795.388035
# 45  해운대구   QR  144745.908210
# 46  해운대구   코나   22602.487566
# 47  해운대구   하나   22235.049561

# %%
top_3.to_csv('구별카드사평균거래금액.csv', index=False)

# %%
# 구별 카드사 중위수 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '카드사명']).median('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 평균과 비슷
# Out:
#     시군구명 카드사명      거래금액
# 0    강서구   QR  130000.0
# 1    강서구   코나   10000.0
# 2    강서구   농협    9800.0
# 3    금정구   QR   19015.0
# 4    금정구   코나    8000.0
# 5    금정구   하나    7750.0
# 6    기장군   QR  150000.0
# 7    기장군   코나   10650.0
# 8    기장군   하나   10200.0
# 9     남구   QR   30000.0
# 10    남구   코나    8400.0
# 11    남구   부산    8000.0
# 12    동구   농협    8000.0
# 13    동구   코나    8000.0
# 14    동구   부산    7750.0
# 15   동래구   QR   31000.0
# 16   동래구   코나    8700.0
# 17   동래구   부산    8420.0
# 18  부산진구   QR   23000.0
# 19  부산진구   코나    8500.0
# 20  부산진구   농협    8000.0
# 21    북구   QR   26000.0
# 22    북구   코나    9000.0
# 23    북구   부산    8500.0
# 24   사상구   QR   17000.0
# 25   사상구   코나    9000.0
# 26   사상구   하나    9000.0
# 27   사하구   QR   46000.0
# 28   사하구   코나    8560.0
# 29   사하구   농협    8300.0
# 30    서구   QR   18000.0
# 31    서구   코나    7900.0
# 32    서구   부산    7600.0
# 33   수영구   QR   18450.0
# 34   수영구   코나    8750.0
# 35   수영구   하나    8557.5
# 36   연제구   QR   50000.0
# 37   연제구   코나    8000.0
# 38   연제구   하나    8000.0
# 39   영도구   QR   19750.0
# 40   영도구   코나    8800.0
# 41   영도구   하나    8600.0
# 42    중구   QR   11000.0
# 43    중구   코나    9400.0
# 44    중구   부산    9000.0
# 45  해운대구   QR   60000.0
# 46  해운대구   코나    8800.0
# 47  해운대구   하나    8400.0

# %%
top_3.to_csv('구별카드사중위거래금액.csv', index=False)

# %%
# 구별 카드사 최대 건당 거래금액 상위 3개
grouped=df.groupby(['시군구명', '카드사명']).max('거래금액')['거래금액'].reset_index(name='거래금액')
top_3=grouped.groupby('시군구명').apply(lambda x: x.nlargest(3, '거래금액')).reset_index(drop=True)
top_3
# 오히려 최대에는 QR이 많이 없는 것으로 보아 QR은 비싼것을 주로 사지만 아주 비싼 것을 사지는 않는듯.
# 당연히 농협은 없음.
# Out:
#     시군구명 카드사명     거래금액
# 0    강서구   하나  1100000
# 1    강서구   QR  1000000
# 2    강서구   부산  1000000
# 3    금정구   부산  1430000
# 4    금정구   코나  1300000
# 5    금정구   하나  1300000
# 6    기장군   코나  1100000
# 7    기장군   부산  1000000
# 8    기장군   하나   980000
# 9     남구   코나  1470000
# 10    남구   부산  1400000
# 11    남구   하나  1300000
# 12    동구   부산  1970000
# 13    동구   코나  1410000
# 14    동구   하나  1180000
# 15   동래구   부산  1300000
# 16   동래구   코나  1230000
# 17   동래구   하나  1200000
# 18  부산진구   부산  1700000
# 19  부산진구   하나  1690000
# 20  부산진구   코나  1580000
# 21    북구   코나  1600000
# 22    북구   QR  1220000
# 23    북구   부산  1000000
# 24   사상구   코나  1350000
# 25   사상구   부산  1050000
# 26   사상구   하나  1030000
# 27   사하구   부산  1400000
# 28   사하구   코나  1209800
# 29   사하구   하나  1076600
# 30    서구   코나  1300000
# 31    서구   하나  1000000
# 32    서구   부산   910000
# 33   수영구   코나  1500000
# 34   수영구   하나  1200000
# 35   수영구   부산  1000000
# 36   연제구   코나  1700000
# 37   연제구   부산  1500000
# 38   연제구   QR  1270000
# 39   영도구   코나  1000000
# 40   영도구   하나   800000
# 41   영도구   부산   780000
# 42    중구   부산  1100000
# 43    중구   코나  1000000
# 44    중구   하나  1000000
# 45  해운대구   코나  1530000
# 46  해운대구   부산  1500000
# 47  해운대구   하나  1400000

# %%
top_3.to_csv('구별카드사최다거래금액.csv', index=False)
